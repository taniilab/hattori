# %%
# %run -i main_v2.py
# Out:
# 0
# じゅ
# ぴっぴ
# 6
# じゅ
# ぴっぴ
# 12
# じゅ
# ぴっぴ
# 18
# じゅ
# ぴっぴ
# 24
# じゅ
# ぴっぴ
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\Hattori\Documents\github\hattori\neuron_HR\main_v2.py in <module>()
#     170
#     171 if __name__ == '__main__':
# --> 172     main()
#
# C:\Users\Hattori\Documents\github\hattori\neuron_HR\main_v2.py in main()
#      90     for i in range(0, main.cycle_multiproc):
#      91         pool = Pool(process)
# ---> 92         cb = pool.map(main.simulate, range(process))
#      93
#      94         print(main.multiproc_co)
#
# C:\Users\Hattori\AppData\Local\Continuum\Anaconda3\lib\multiprocessing\pool.py in map(self, func, iterable, chunksize)
#     258         in a list that is returned.
#     259         '''
# --> 260         return self._map_async(func, iterable, mapstar, chunksize).get()
#     261
# ...

# %%
# %run -i main_v2.py
# Out:
#   File "C:\Users\Hattori\Documents\github\hattori\neuron_HR\main_v2.py", line 7
#     %matplotlib inline
#     ^
# SyntaxError: invalid syntax

# %%
# %matplotlib inline
# %run -i main_v2.py
# Out:
# 0
# じゅ
# ぴっぴ
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\Hattori\Documents\github\hattori\neuron_HR\main_v2.py in <module>()
#     175
#     176 if __name__ == '__main__':
# --> 177     main()
#
# C:\Users\Hattori\Documents\github\hattori\neuron_HR\main_v2.py in main()
#      94     for i in range(0, main.cycle_multiproc):
#      95         pool = Pool(process)
# ---> 96         cb = pool.map(main.simulate, range(process))
#      97
#      98         print(main.multiproc_co)
#
# C:\Users\Hattori\AppData\Local\Continuum\Anaconda3\lib\multiprocessing\pool.py in map(self, func, iterable, chunksize)
#     258         in a list that is returned.
#     259         '''
# --> 260         return self._map_async(func, iterable, mapstar, chunksize).get()
#     261
#     262     def starmap(self, func, iterable, chunksize=None):
#
# ...

# %%
# %matplotlib inline
from PIL import Image
img = np.array(Image.open('junon.jpg'))
plt.imshow(img)
